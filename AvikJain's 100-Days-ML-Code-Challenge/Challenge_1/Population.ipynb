# %%
import os
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
os.chdir("C:/Users/gulte/Desktop/AI Exercises/Challenge_1")

# %%
df = pd.read_csv("world_population_1960_2015.csv",encoding="cp1252")

# %%
df.shape
# Out:
# (264, 57)

# %%
df.isnull().sum().sum()
# Out:
# 161

# %%
df.dropna(axis = 0,inplace=True)

# %%
# For better handling of df, I only picked numerical columns
df_numeric = df.drop("Country Name",axis=1)

# %%
df_numeric.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015'],
#       dtype='object')

# %%
df_numeric.isnull().sum().sum()
# Out:
# 0

# %%
df_numeric.dropna(axis = 0,inplace=True)

# %%
df_numeric.shape
# Out:
# (258, 56)

# %%
df_numeric = df_numeric.astype(int)

# %%
df_numeric.head()
# Out:
#       1960     1961     1962     1963     1964     1965      1966      1967  \
# 0    54208    55435    56226    56697    57029    57360     57712     58049
# 1    13414    14376    15376    16410    17470    18551     19646     20755
# 2  8994793  9164945  9343772  9531555  9728645  9935358  10148841  10368600
# 3  5270844  5367287  5465905  5565808  5665701  5765025   5863568   5962831
# 4  1608800  1659800  1711319  1762621  1814135  1864791   1914573   1965598
#
#        1968      1969  ...      2006      2007      2008      2009      2010  \
# 0     58385     58724  ...    100830    101218    101342    101416    101597
# 1     21888     23061  ...     83373     84878     85616     85474     84419
# 2  10599790  10849510  ...  25183615  25877544  26528741  27207291  27962207
# 3   6066094   6177703  ...  18541467  19183907  19842251  20520103  21219954
# 4   2022272   2081695  ...   2992547   2970017   2947314   2927519   2913021
#
# ...

# %%
df_country = df.filter(["Country Name"],axis=1)

# %%
df_country.shape
# Out:
# (258, 1)

# %%
df_n = pd.concat([df_country,df_numeric],axis=1)

# %%
df_n
# Out:
#          Country Name      1960      1961      1962      1963      1964  \
# 0               Aruba     54208     55435     56226     56697     57029
# 1             Andorra     13414     14376     15376     16410     17470
# 2         Afghanistan   8994793   9164945   9343772   9531555   9728645
# 3              Angola   5270844   5367287   5465905   5565808   5665701
# 4             Albania   1608800   1659800   1711319   1762621   1814135
# ..                ...       ...       ...       ...       ...       ...
# 259       Yemen, Rep.   5166311   5251663   5339285   5429501   5522690
# 260      South Africa  17396000  17949962  18459442  18936138  19390554
# 261  Congo, Dem. Rep.  15248246  15637715  16041247  16461914  16903899
# 262            Zambia   3049586   3142848   3240664   3342894   3449266
# 263          Zimbabwe   3752390   3876638   4006262   4140804   4279561
#
#          1965      1966      1967      1968  ...      2006      2007  \
# ...

# %%
test_size = 5

# %%
df_train = df_n.iloc[:,:-5]
df_train
# Out:
#          Country Name      1960      1961      1962      1963      1964  \
# 0               Aruba     54208     55435     56226     56697     57029
# 1             Andorra     13414     14376     15376     16410     17470
# 2         Afghanistan   8994793   9164945   9343772   9531555   9728645
# 3              Angola   5270844   5367287   5465905   5565808   5665701
# 4             Albania   1608800   1659800   1711319   1762621   1814135
# ..                ...       ...       ...       ...       ...       ...
# 259       Yemen, Rep.   5166311   5251663   5339285   5429501   5522690
# 260      South Africa  17396000  17949962  18459442  18936138  19390554
# 261  Congo, Dem. Rep.  15248246  15637715  16041247  16461914  16903899
# 262            Zambia   3049586   3142848   3240664   3342894   3449266
# 263          Zimbabwe   3752390   3876638   4006262   4140804   4279561
#
#          1965      1966      1967      1968  ...      2001      2002  \
# ...

# %%
df_test_raw = df_n.iloc[:,-5:]
df_test = pd.concat([df_country,df_test_raw],axis=1)
df_test
# Out:
#          Country Name      2011      2012      2013      2014      2015
# 0               Aruba    101936    102393    102921    103441    103889
# 1             Andorra     82326     79316     75902     72786     70473
# 2         Afghanistan  28809167  29726803  30682500  31627506  32526562
# 3              Angola  21942296  22685632  23448202  24227524  25021974
# 4             Albania   2904780   2900247   2896652   2893654   2889167
# ..                ...       ...       ...       ...       ...       ...
# 259       Yemen, Rep.  24234940  24882792  25533217  26183676  26832215
# 260      South Africa  51549958  52356381  53192216  54058647  54956920
# 261  Congo, Dem. Rep.  68087376  70291160  72552861  74877030  77266814
# 262            Zambia  14343526  14786581  15246086  15721343  16211767
# 263          Zimbabwe  14255592  14565482  14898092  15245855  15602751
#
# [258 rows x 6 columns]

# %%
df_test.to_csv("./TestPop.csv", sep = ',', index = False)
df_train.to_csv("./TrainPop.csv", sep = ',', index = False)

# %%
df_test.head()
# Out:
#   Country Name      2011      2012      2013      2014      2015
# 0        Aruba    101936    102393    102921    103441    103889
# 1      Andorra     82326     79316     75902     72786     70473
# 2  Afghanistan  28809167  29726803  30682500  31627506  32526562
# 3       Angola  21942296  22685632  23448202  24227524  25021974
# 4      Albania   2904780   2900247   2896652   2893654   2889167

# %%
df_train.head(10)
# Out:
#            Country Name      1960      1961      1962       1963       1964  \
# 0                 Aruba     54208     55435     56226      56697      57029
# 1               Andorra     13414     14376     15376      16410      17470
# 2           Afghanistan   8994793   9164945   9343772    9531555    9728645
# 3                Angola   5270844   5367287   5465905    5565808    5665701
# 4               Albania   1608800   1659800   1711319    1762621    1814135
# 5            Arab World  92540534  95077992  97711191  100439395  103263656
# 6  United Arab Emirates     92612    100985    112240     125216     138220
# 7             Argentina  20619075  20953079  21287682   21621845   21953926
# 8               Armenia   1867396   1934239   2002170    2070427    2138133
# 9        American Samoa     20012     20478     21118      21883      22701
#
#         1965       1966       1967       1968  ...       2001       2002  \
# ...

# %%
scaler = StandardScaler()

# %%
scaled = scaler.fit_transform(df_test.iloc[:,1:])
df_test_scaled = pd.DataFrame(scaled,index = df_test.index,columns = df_test.columns[1:])

# %%
df_test_final = pd.concat([df_country, df_test_scaled],axis=1)
df_test_final
# Out:
#          Country Name      2011      2012      2013      2014      2015
# 0               Aruba -0.081099 -0.083897 -0.086847 -0.089684 -0.092553
# 1             Andorra -0.081134 -0.083939 -0.086896 -0.089739 -0.092612
# 2         Afghanistan -0.028937 -0.030342 -0.031863 -0.033303 -0.034880
# 3              Angola -0.041415 -0.043071 -0.044871 -0.046538 -0.048229
# 4             Albania -0.076006 -0.078839 -0.081824 -0.084694 -0.087598
# ..                ...       ...       ...       ...       ...       ...
# 259       Yemen, Rep. -0.037249 -0.039099 -0.041122 -0.043039 -0.045009
# 260      South Africa  0.012383  0.010567  0.008611  0.006816  0.005018
# 261  Congo, Dem. Rep.  0.042431  0.042990  0.043423  0.044050  0.044702
# 262            Zambia -0.055222 -0.057351 -0.059619 -0.061751 -0.063901
# 263          Zimbabwe -0.055381 -0.057751 -0.060244 -0.062602 -0.064984
#
# [258 rows x 6 columns]

# %%
scaled2 = scaler.fit_transform(df_train.iloc[:,1:])
df_train_scaled = pd.DataFrame(scaled2, index=df_train.index, columns = df_train.columns[1:])

# %%
df_train_final = pd.concat([df_country, df_train_scaled],axis=1)

# %%
df_train_final
# Out:
#          Country Name      1960      1961      1962      1963      1964  \
# 0               Aruba -0.181904 -0.136695 -0.139687 -0.143160 -0.146596
# 1             Andorra -0.182018 -0.136809 -0.139799 -0.143269 -0.146703
# 2         Afghanistan -0.156800 -0.111458 -0.114139 -0.117348 -0.120503
# 3              Angola -0.167256 -0.121979 -0.124806 -0.128152 -0.131465
# 4             Albania -0.177539 -0.132251 -0.135134 -0.138512 -0.141856
# ..                ...       ...       ...       ...       ...       ...
# 259       Yemen, Rep. -0.167550 -0.122300 -0.125155 -0.128523 -0.131850
# 260      South Africa -0.133210 -0.087120 -0.089065 -0.091728 -0.094437
# 261  Congo, Dem. Rep. -0.139241 -0.093526 -0.095716 -0.098469 -0.101146
# 262            Zambia -0.173493 -0.128142 -0.130927 -0.134207 -0.137444
# 263          Zimbabwe -0.171520 -0.126109 -0.128821 -0.132034 -0.135204
#
#          1965      1966      1967      1968  ...      2001      2002  \
# ...
